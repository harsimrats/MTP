# %%
import pickle as pkl
import matplotlib.pyplot as plt
# %matplotlib inline
ssTableData = {}
separator = ":"
# namePrefix = sys.argv[3]
namePrefix = "svmsimplebagofword4lessdata"
# namePrefix = "epsilonbagofword8"
namePrefixOri = namePrefix


takesample = False

# typedata = sys.argv[1]
typedata = "vdisk"
if typedata=="vdisk":
    import vdiskHelper as dataHelper
# typemodel = sys.argv[2]
typemodel = "svmsimple"
# typemodel = "epsilon"
if typemodel=="epsilon":
    import epsilonHelper as modelHelper
elif typemodel=="svmsimple":
    import svmsklearncoreHelper as modelHelper
elif typemodel=="libsvmsch":
    import svmlibsvmHelper as modelHelper
elif typemodel=="isolationforest":
    print("isolationforest loaded")
    import isolationForestHelper as modelHelper
    
f = open("Observations/compiledobs_"+namePrefix+".pkl","rb")
wholejson = pkl.load(f)
f.close()
fprs = []
sizes = []
bfsizes = []
nsv = []
nus = []
gammas = []
tols = []

for i in wholejson["data"]:
#     if i["fpr"] >0.31:
#         continue
#     if i["nsv"]*1.0/839364 > 0.17:
#         continue
    fprs.append(i["fpr"])
    sizes.append(i["size"])
    bfsizes.append(i["bfsize"])
#     nsv.append(i["nsv"]*1.0/839364)
#     nus.append(i["nu"])
#     gammas.append(i["gamma"])
#     tols.append(i["tol"])
    print(i)
# print(x, y)
# print(sizes)
fig, ax1 = plt.subplots()
fig.set_size_inches(18.5, 10.5)
# plt.scatter(fprs,nsv, color='green', alpha=0.7)
# for i in range(len(fprs)):
#     plt.annotate("nu:"+str(nus[i])+" gamma: "+str(gammas[i])+" tol: "+str(tols[i]), xy=(fprs[i],nsv[i]))
# for i in range(len(fprs)):
#     plt.annotate("nu:"+str(nus[i])+" gamma: "+str(gammas[i])+" tol: "+str(tols[i]), xy=(fprs[i],nsv[i]))
ax1.set_ylabel("support vector ratio (green)")
# ax2 = ax1.twinx() 
sizesMultBfsizes = []
for i in range(len(bfsizes)):
    sizesMultBfsizes.append(bfsizes[i] * sizes[i])
print(sizesMultBfsizes)
plt.scatter(fprs,sizesMultBfsizes, color='blue', alpha=0.7)
# for i in range(len(fprs)):
#     plt.plot([fprs[i], fprs[i]], [nsv[i],bfsizes[i]], 'ro-')
# ax2.set_ylabel("bloom filter sizes (blue)")
# plt.scatter(fprs,nsv)
ax1.set_xlabel("false positive rate")
# plt.ylabel("size")
# plt.vlines(x=[0.3], ymin=min(y), ymax=max(y), color ='red')
plt.title('One Class svm sklearn, bag of words (3) sparse vdisk data')
plt.show()
# Out:
# {'nu': 0.001, 'gamma': 0.1, 'kernel': 'rbf', 'tol': 0.001, 'fpr': 0.3058599534588534, 'falsenegative_c': 431001, 'falsepositive_c': 250, 'falsepositive_bf': 14208, 'bfsize': 135009.5, 'size': 6777130752, 'nsv': 124096}
# {'nu': 0.001, 'gamma': 0.1, 'kernel': 'rbf', 'tol': 0.01, 'fpr': 0.30742542839009945, 'falsenegative_c': 615934, 'falsepositive_c': 224, 'falsepositive_bf': 14308, 'bfsize': 192937.75, 'size': 1043034588, 'nsv': 19099}
# {'nu': 0.001, 'gamma': 0.1, 'kernel': 'rbf', 'tol': 0.1, 'fpr': 0.3061772794584303, 'falsenegative_c': 789979, 'falsepositive_c': 187, 'falsepositive_bf': 14286, 'bfsize': 247454.5, 'size': 171590904, 'nsv': 3142}
# {'nu': 0.001, 'gamma': 0.1, 'kernel': 'rbf', 'tol': 1.0, 'fpr': 0.
 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16]

# %%
import pickle as pkl
import matplotlib.pyplot as plt
from adjustText import adjust_text
# %matplotlib inline
ssTableData = {}
separator = ":"
# namePrefix = sys.argv[3]
namePrefix = "svmsimplebagofword4lessdata"
# namePrefix = "epsilonbagofword8"
namePrefixOri = namePrefix


takesample = False

# typedata = sys.argv[1]
typedata = "vdisk"
if typedata=="vdisk":
    import vdiskHelper as dataHelper
# typemodel = sys.argv[2]
typemodel = "svmsimple"
# typemodel = "epsilon"
if typemodel=="epsilon":
    import epsilonHelper as modelHelper
elif typemodel=="svmsimple":
    import svmsklearncoreHelper as modelHelper
elif typemodel=="libsvmsch":
    import svmlibsvmHelper as modelHelper
elif typemodel=="isolationforest":
    print("isolationforest loaded")
    import isolationForestHelper as modelHelper
    
f = open("Observations/compiledobs_"+namePrefix+".pkl","rb")
wholejson = pkl.load(f)
f.close()
fprs = []
sizes = []
bfsizes = []
nsv = []
nus = []
gammas = []
tols = []
totalDataPoints = None
for i in wholejson["data"]:
#     if i["fpr"] >0.31:
#         continue
#     if i["nsv"]*1.0/839364 > 0.17:
#         continue
    fprs.append(i["fpr"])
    sizes.append(i["size"])
    bfsizes.append(i["bfsize"])
    if totalDataPoints is None:
        totalDataPoints = i["totalDataPoints"]
    nsv.append(i["nsv"]*1.0/totalDataPoints)
    nus.append(i["nu"])
    gammas.append(i["gamma"])
    tols.append(i["tol"])
    print(i)
# print(x, y)
# print(sizes)
fig, ax1 = plt.subplots()
fig.set_size_inches(18.5, 10.5)
# plt.scatter(fprs,nsv, color='green', alpha=0.7)
# for i in range(len(fprs)):
#     plt.annotate("nu:"+str(nus[i])+" gamma: "+str(gammas[i])+" tol: "+str(tols[i]), xy=(fprs[i],nsv[i]))
# for i in range(len(fprs)):
#     plt.annotate(str(nus[i])+", "+str(gammas[i])+", "+str(tols[i]), xy=(fprs[i],nsv[i]))
# texts = [plt.text(fprs[i],nsv[i], str(nus[i])+", "+str(gammas[i])+", "+str(tols[i]), ha='center', va='center') for i in range(len(fprs))]
texts = [plt.text(fprs[i],nsv[i], "nu:"+str(nus[i])+" gamma: "+str(gammas[i])+" tol: "+str(tols[i]), ha='center', va='center') for i in range(len(fprs))]

adjust_text(texts, arrowprops=dict(arrowstyle='->', color='black'))
ax1.set_ylabel("support vector ratio (green)")
# ax2 = ax1.twinx() 
sizesMultBfsizes = []
for i in range(len(bfsizes)):
    sizesMultBfsizes.append(bfsizes[i] * sizes[i])
print(sizesMultBfsizes)
plt.scatter(fprs,nsv, color='blue', alpha=0.7)
# for i in range(len(fprs)):
#     plt.plot([fprs[i], fprs[i]], [nsv[i],bfsizes[i]], 'ro-')
# ax2.set_ylabel("bloom filter sizes (blue)")
# plt.scatter(fprs,nsv)
ax1.set_xlabel("false positive rate")
# plt.ylabel("size")
# plt.vlines(x=[0.3], ymin=min(y), ymax=max(y), color ='red')
plt.title('One Class svm sklearn, bag of words (3) sparse vdisk data')
plt.show()
# Out:
# {'nu': 0.001, 'gamma': 0.1, 'kernel': 'rbf', 'tol': 0.001, 'fpr': 0.9, 'falsenegative_c': 598, 'falsepositive_c': 9, 'falsepositive_bf': 0, 'totalDataPoints': 2895, 'bfsize': 188.0, 'size': 3684852, 'nsv': 243}
# {'nu': 0.001, 'gamma': 0.1, 'kernel': 'rbf', 'tol': 0.01, 'fpr': 0.7, 'falsenegative_c': 2669, 'falsepositive_c': 3, 'falsepositive_bf': 4, 'totalDataPoints': 2895, 'bfsize': 836.75, 'size': 834020, 'nsv': 55}
# {'nu': 0.001, 'gamma': 0.1, 'kernel': 'rbf', 'tol': 0.1, 'fpr': 0.3, 'falsenegative_c': 2895, 'falsepositive_c': 0, 'falsepositive_bf': 3, 'totalDataPoints': 2895, 'bfsize': 907.5, 'size':

#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.3058599534588534,
#    'falsenegative_c': 431001,
#    'falsepositive_c': 250,
#    'falsepositive_bf': 14208,
#    'bfsize': 135009.5,
#    'size': 6777130752,
#    'nsv': 124096},
#   {'nu': 0.001,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.30742542839009945,
#    'falsenegative_c': 615934,
#    'falsepositive_c': 224,
#    'falsepositive_bf': 14308,
#    'bfsize': 192937.75,
#    'size': 1043034588,
#    'nsv': 19099},
#   {'nu': 0.001,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.3061772794584303,
#    'falsenegative_c': 789979,
#    'falsepositive_c': 187,
#    'falsepositive_bf': 14286,
#    'bfsize': 247454.5,
#    'size': 171590904,
#    'nsv': 3142},
#   {'nu': 0.001,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.3015020097313307,
#    'falsenegative_c': 832734,
#    'falsepositive_c': 138,
#    'falsepositive_bf': 14114,
#    'bfsize': 260847.75,
#    'size': 46474812,
#    'nsv': 851},
#   {'nu': 0.001,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.3053945419928073,
#    'falsenegative_c': 815192,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14436,
#    'bfsize': 255353.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.001,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.30393484239475355,
#    'falsenegative_c': 751451,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14367,
#    'bfsize': 235387.0,
#    'size': 5882258520,
#    'nsv': 107710},
#   {'nu': 0.001,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.30528876665961496,
#    'falsenegative_c': 836714,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14431,
#    'bfsize': 262094.5,
#    'size': 733166100,
#    'nsv': 13425},
#   {'nu': 0.001,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.3023693674635075,
#    'falsenegative_c': 838874,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14293,
#    'bfsize': 262771.75,
#    'size': 91638936,
#    'nsv': 1678},
#   {'nu': 0.001,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.3048022001269304,
#    'falsenegative_c': 815192,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14408,
#    'bfsize': 255353.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.001,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.3038079119949228,
#    'falsenegative_c': 751388,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14361,
#    'bfsize': 235367.5,
#    'size': 5882258520,
#    'nsv': 107710},
#   {'nu': 0.001,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.305563782525915,
#    'falsenegative_c': 836727,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14444,
#    'bfsize': 262098.5,
#    'size': 733166100,
#    'nsv': 13425},
#   {'nu': 0.001,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.3024328326634229,
#    'falsenegative_c': 838874,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14296,
#    'bfsize': 262771.75,
#    'size': 91638936,
#    'nsv': 1678},
#   {'nu': 0.01,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.30820816585572247,
#    'falsenegative_c': 254720,
#    'falsepositive_c': 194,
#    'falsepositive_bf': 14375,
#    'bfsize': 79791.25,
#    'size': 21305615724,
#    'nsv': 390127},
#   {'nu': 0.01,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.30751004865665327,
#    'falsenegative_c': 431735,
#    'falsepositive_c': 190,
#    'falsepositive_bf': 14346,
#    'bfsize': 135240.0,
#    'size': 6960845520,
#    'nsv': 127460},
#   {'nu': 0.01,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.30753120372329174,
#    'falsenegative_c': 614663,
#    'falsepositive_c': 182,
#    'falsepositive_bf': 14355,
#    'bfsize': 192539.75,
#    'size': 1117962252,
#    'nsv': 20471},
#   {'nu': 0.01,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.30321557012904593,
#    'falsenegative_c': 799855,
#    'falsepositive_c': 148,
#    'falsepositive_bf': 14185,
#    'bfsize': 250548.25,
#    'size': 458959248,
#    'nsv': 8404},
#   {'nu': 0.01,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.30145969959805374,
#    'falsenegative_c': 637364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14250,
#    'bfsize': 199650.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.01,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.3016924053310768,
#    'falsenegative_c': 603992,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14261,
#    'bfsize': 189197.0,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.01,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.30368098159509205,
#    'falsenegative_c': 779769,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14355,
#    'bfsize': 244256.75,
#    'size': 7333463196,
#    'nsv': 134283},
#   {'nu': 0.01,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.3055426274592765,
#    'falsenegative_c': 832174,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14443,
#    'bfsize': 260672.5,
#    'size': 915952464,
#    'nsv': 16772},
#   {'nu': 0.01,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.30027501586629995,
#    'falsenegative_c': 637364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14194,
#    'bfsize': 199650.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.01,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.3011212185318384,
#    'falsenegative_c': 603992,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14234,
#    'bfsize': 189197.0,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.01,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.30664269092447644,
#    'falsenegative_c': 776866,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14495,
#    'bfsize': 243347.5,
#    'size': 7333299360,
#    'nsv': 134280},
#   {'nu': 0.01,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.30154431986460756,
#    'falsenegative_c': 832299,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14254,
#    'bfsize': 260711.5,
#    'size': 916607808,
#    'nsv': 16784},
#   {'nu': 0.1,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.30569071292574573,
#    'falsenegative_c': 128300,
#    'falsepositive_c': 165,
#    'falsepositive_bf': 14285,
#    'bfsize': 40191.0,
#    'size': 27974232432,
#    'nsv': 512236},
#   {'nu': 0.1,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.30505606092659193,
#    'falsenegative_c': 287889,
#    'falsepositive_c': 165,
#    'falsepositive_bf': 14255,
#    'bfsize': 90180.75,
#    'size': 24498833976,
#    'nsv': 448598},
#   {'nu': 0.1,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.30450602919399195,
#    'falsenegative_c': 476398,
#    'falsepositive_c': 160,
#    'falsepositive_bf': 14234,
#    'bfsize': 149229.25,
#    'size': 7713726552,
#    'nsv': 141246},
#   {'nu': 0.1,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.3045483393272689,
#    'falsenegative_c': 535680,
#    'falsepositive_c': 185,
#    'falsepositive_bf': 14211,
#    'bfsize': 167799.0,
#    'size': 4584513564,
#    'nsv': 83947},
#   {'nu': 0.1,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.30368098159509205,
#    'falsenegative_c': 503566,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14355,
#    'bfsize': 157739.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.1,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.30598688385868417,
#    'falsenegative_c': 167931,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14464,
#    'bfsize': 52605.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.1,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.3033213454622382,
#    'falsenegative_c': 335765,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14338,
#    'bfsize': 105177.75,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.1,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.3020731965305691,
#    'falsenegative_c': 749936,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14279,
#    'bfsize': 234912.0,
#    'size': 9121187016,
#    'nsv': 167018},
#   {'nu': 0.1,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.3019674211973768,
#    'falsenegative_c': 503584,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14274,
#    'bfsize': 157744.75,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.1,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.3045906494605458,
#    'falsenegative_c': 167952,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14398,
#    'bfsize': 52611.75,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.1,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.3024539877300613,
#    'falsenegative_c': 335756,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14297,
#    'bfsize': 105174.75,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 0.1,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.30387137719483814,
#    'falsenegative_c': 752698,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14364,
#    'bfsize': 235777.5,
#    'size': 9167716440,
#    'nsv': 167870},
#   {'nu': 1.0,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 0.1,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 10.0,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.001,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.01,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 0.1,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364},
#   {'nu': 1.0,
#    'gamma': 1000.0,
#    'kernel': 'rbf',
#    'tol': 1.0,
#    'fpr': 0.3002115506663846,
#    'falsenegative_c': 839364,
#    'falsepositive_c': 0,
#    'falsepositive_bf': 14191,
#    'bfsize': 262924.25,
#    'size': 45839346768,
#    'nsv': 839364}]}

# %%
sizesMultBfsizescopy = sizesMultBfsizes.copy()
sizesMultBfsizescopy.sort()
print(sizesMultBfsizescopy)
# Out:
# [12122850141873.0, 24080123580858.0, 24080123580858.0, 42460941353868.0, 114991436407716.0, 192158802396450.0, 192161735060850.0, 201240746580897.0, 215252172509517.0, 238763618672040.0, 238970196535392.0, 769276791525636.0, 914977034262144.0, 941384748124800.0, 1124312375674512.0, 1151113628060046.0, 1384492482206100.0, 1384607186247240.0, 1700001710637615.0, 1784540066007600.0, 1791247886499573.0, 2142676284302592.0, 2161541262932100.0, 2209323222081162.0, 2411390296567332.0, 2411688252321324.0, 4821141836487708.0, 4821279354528012.0, 7230664179674244.0, 7230916296081468.0, 8672666890465296.0, 8672666890465296.0, 9151837042067892.0, 9151837042067892.0, 1.1705226175085796e+16, 1.1705226175085796e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16, 1.2052275869466324e+16]

# %%
import pickle as pkl
import matplotlib.pyplot as plt
# %matplotlib inline
ssTableData = {}
separator = ":"
# namePrefix = sys.argv[3]
# namePrefix = "svmsimplebagofword5"
namePrefix = "epsilonbagofword8"
namePrefixOri = namePrefix


takesample = False

# typedata = sys.argv[1]
typedata = "vdisk"
if typedata=="vdisk":
    import vdiskHelper as dataHelper
# typemodel = sys.argv[2]
# typemodel = "svmsimple"
typemodel = "epsilon"
if typemodel=="epsilon":
    import epsilonHelper as modelHelper
elif typemodel=="svmsimple":
    import svmsklearncoreHelper as modelHelper
elif typemodel=="libsvmsch":
    import svmlibsvmHelper as modelHelper
elif typemodel=="isolationforest":
    print("isolationforest loaded")
    import isolationForestHelper as modelHelper
    
f = open("Observations/compiledobs_"+namePrefix+".pkl","rb")
wholejson = pkl.load(f)
f.close()
fprs = []
sizes = []
bfsizes = []
nsv = []
nus = []
gammas = []
tols = []
Ds = []
epsilons = []
agg_thrs = []
box_thrs = []

for i in wholejson["data"]:
#     if i["fpr"] >0.31:
#         continue
#     if i["nsv"]*1.0/839364 > 0.17:
#         continue
    fprs.append(i["fpr"])
    sizes.append(i["size"])
    bfsizes.append(i["bfsize"])
#     nsv.append(i["nsv"]*1.0/839364)
#     nus.append(i["nu"])
#     gammas.append(i["gamma"])
#     tols.append(i["tol"])
    Ds.append(i["D"])
    epsilons.append(i["epsilon"])
    agg_thrs.append(i["agg_thr"])
    box_thrs.append(i["box_thr"])
#     print(i)
# print(x, y)
# print(sizes)
fig, ax1 = plt.subplots()
fig.set_size_inches(18.5, 10.5)
# plt.scatter(fprs,nsv, color='green', alpha=0.7)
# for i in range(len(fprs)):
#     plt.annotate("nu:"+str(nus[i])+" gamma: "+str(gammas[i])+" tol: "+str(tols[i]), xy=(fprs[i],nsv[i]))
# for i in range(len(fprs)):
#     plt.annotate("D:"+str(Ds[i])+" epsilon: "+str(epsilons[i])+" agg_thr: "+str(agg_thrs[i])+" box_thr: "+str(box_thrs[i]), xy=(fprs[i],bfsizes[i]))
ax1.set_ylabel("support vector ratio (green)")
# ax2 = ax1.twinx() 
plt.scatter(fprs,sizes, color='blue', alpha=0.7)
# for i in range(len(fprs)):
#     plt.plot([fprs[i], fprs[i]], [nsv[i],bfsizes[i]], 'ro-')
# ax2.set_ylabel("bloom filter sizes (blue)")
# plt.scatter(fprs,nsv)
ax1.set_xlabel("false positive rate")
# plt.ylabel("size")
# plt.vlines(x=[0.3], ymin=min(y), ymax=max(y), color ='red')
plt.title('One Class svm sklearn, bag of words (3) sparse vdisk data')
plt.show()

# %%
import pickle as pkl
import matplotlib.pyplot as plt
# %matplotlib inline
ssTableData = {}
separator = ":"
# namePrefix = sys.argv[3]
# namePrefix = "svmsimplebagofword5"
namePrefix = "epsilonbagofword4lessdata"
namePrefixOri = namePrefix


takesample = False

# typedata = sys.argv[1]
typedata = "vdisk"
if typedata=="vdisk":
    import vdiskHelper as dataHelper
# typemodel = sys.argv[2]
# typemodel = "svmsimple"
typemodel = "epsilon"
if typemodel=="epsilon":
    import epsilonHelper as modelHelper
elif typemodel=="svmsimple":
    import svmsklearncoreHelper as modelHelper
elif typemodel=="libsvmsch":
    import svmlibsvmHelper as modelHelper
elif typemodel=="isolationforest":
    print("isolationforest loaded")
    import isolationForestHelper as modelHelper
    
f = open("Observations/compiledobs_"+namePrefix+".pkl","rb")
wholejson = pkl.load(f)
f.close()
fprs = []
sizes = []
bfsizes = []
nsv = []
nus = []
gammas = []
tols = []
Ds = []
epsilons = []
agg_thrs = []
box_thrs = []

for i in wholejson["data"]:
#     if i["fpr"] >0.31:
#         continue
#     if i["nsv"]*1.0/839364 > 0.17:
#         continue
    fprs.append(i["fpr"])
    sizes.append(i["size"])
    bfsizes.append(i["bfsize"])
#     nsv.append(i["nsv"]*1.0/839364)
#     nus.append(i["nu"])
#     gammas.append(i["gamma"])
#     tols.append(i["tol"])
    Ds.append(i["D"])
    epsilons.append(i["epsilon"])
    agg_thrs.append(i["agg_thr"])
    box_thrs.append(i["box_thr"])
#     print(i)
# print(x, y)
# print(sizes)
fig, ax1 = plt.subplots()
fig.set_size_inches(18.5, 10.5)
# plt.scatter(fprs,nsv, color='green', alpha=0.7)
# for i in range(len(fprs)):
#     plt.annotate("nu:"+str(nus[i])+" gamma: "+str(gammas[i])+" tol: "+str(tols[i]), xy=(fprs[i],nsv[i]))
# for i in range(len(fprs)):
#     plt.annotate("D:"+str(Ds[i])+" epsilon: "+str(epsilons[i])+" agg_thr: "+str(agg_thrs[i])+" box_thr: "+str(box_thrs[i]), xy=(fprs[i],bfsizes[i]))
ax1.set_ylabel("support vector ratio (green)")
# ax2 = ax1.twinx() 
plt.scatter(fprs,sizes, color='blue', alpha=0.7)
# for i in range(len(fprs)):
#     plt.plot([fprs[i], fprs[i]], [nsv[i],bfsizes[i]], 'ro-')
# ax2.set_ylabel("bloom filter sizes (blue)")
# plt.scatter(fprs,nsv)
ax1.set_xlabel("false positive rate")
# plt.ylabel("size")
# plt.vlines(x=[0.3], ymin=min(y), ymax=max(y), color ='red')
plt.title('One Class svm sklearn, bag of words (3) sparse vdisk data')
plt.show()

# %%
(max(bfsizes), min(bfsizes))
# Out:
# (262771.75, 135009.5)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
# np.random.seed(19680801)

# the random data
print(x)
print(y)
print("dfsf")



# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a rectangular Figure
plt.figure(figsize=(8, 8))

ax_scatter = plt.axes(rect_scatter)
ax_scatter.tick_params(direction='in', top=True, right=True)
ax_histx = plt.axes(rect_histx)
ax_histx.tick_params(direction='in', labelbottom=False)
ax_histy = plt.axes(rect_histy)
ax_histy.tick_params(direction='in', labelleft=False)

# the scatter plot:
ax_scatter.scatter(x, y)

# now determine nice limits by hand:
binwidth = 0.25
lim = np.ceil(np.abs([x, y]).max() / binwidth) * binwidth
ax_scatter.set_xlim((-lim, lim))
ax_scatter.set_ylim((-lim, lim))

bins = np.arange(-lim, lim + binwidth, binwidth)
ax_histx.hist(x, bins=bins)
ax_histy.hist(y, bins=bins, orientation='horizontal')

ax_histx.set_xlim(ax_scatter.get_xlim())
ax_histy.set_ylim(ax_scatter.get_ylim())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c9e23a1ed19d> in <module>
#       6
#       7 # the random data
# ----> 8 print(x)
#       9 print(y)
#      10 print("dfsf")
#
# NameError: name 'x' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

# the random data
x = np.random.randn(1000)
y = np.random.randn(1000)

# print(x)
# print(y)
# print("dfsf")

# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a rectangular Figure
plt.figure(figsize=(8, 8))

ax_scatter = plt.axes(rect_scatter)
ax_scatter.tick_params(direction='in', top=True, right=True)
ax_histx = plt.axes(rect_histx)
ax_histx.tick_params(direction='in', labelbottom=False)
ax_histy = plt.axes(rect_histy)
ax_histy.tick_params(direction='in', labelleft=False)

# the scatter plot:
ax_scatter.scatter(x, y)

# now determine nice limits by hand:
binwidth = 0.25
lim = np.ceil(np.abs([x, y]).max() / binwidth) * binwidth
ax_scatter.set_xlim((-lim, lim))
ax_scatter.set_ylim((-lim, lim))

bins = np.arange(-lim, lim + binwidth, binwidth)
print(bins)
ax_histx.hist(x, bins=bins)
ax_histy.hist(y, bins=bins, orientation='horizontal')

ax_histx.set_xlim(ax_scatter.get_xlim())
ax_histy.set_ylim(ax_scatter.get_ylim())

plt.show()
# Out:
# [-4.25 -4.   -3.75 -3.5  -3.25 -3.   -2.75 -2.5  -2.25 -2.   -1.75 -1.5
#  -1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75  1.    1.25  1.5
#   1.75  2.    2.25  2.5   2.75  3.    3.25  3.5   3.75  4.    4.25]

# %%
min(x)

# %%
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(1)

x = np.random.rand(15)
y = np.random.rand(15)
names = np.array(list("ABCDEFGHIJKLMNO"))
c = np.random.randint(1,5,size=15)

norm = plt.Normalize(1,4)
cmap = plt.cm.RdYlGn

fig,ax = plt.subplots()
sc = plt.scatter(x,y,c=c, s=100, cmap=cmap, norm=norm)

annot = ax.annotate("", xy=(0,0), xytext=(20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->"))
annot.set_visible(False)

def update_annot(ind):

    pos = sc.get_offsets()[ind["ind"][0]]
    annot.xy = pos
    text = "{}, {}".format(" ".join(list(map(str,ind["ind"]))), 
                           " ".join([names[n] for n in ind["ind"]]))
    annot.set_text(text)
    annot.get_bbox_patch().set_facecolor(cmap(norm(c[ind["ind"][0]])))
    annot.get_bbox_patch().set_alpha(0.4)


def hover(event):
    vis = annot.get_visible()
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        if cont:
            update_annot(ind)
            annot.set_visible(True)
            fig.canvas.draw_idle()
        else:
            if vis:
                annot.set_visible(False)
                fig.canvas.draw_idle()

fig.canvas.mpl_connect("motion_notify_event", hover)

plt.show()

# %%
wholejson

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
print(x)
print(y)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
print(area)
print(np.min(area), np.max(area))
c = np.sqrt(area)
print(c)
print(np.min(c), np.max(c))
r = np.sqrt(x ** 2 + y ** 2)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
theta = np.arange(0, np.pi / 2, 0.01)
plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))

plt.show()
# Out:
# [0.63033057 0.66847573 0.63835201 0.51007097 0.8800068  0.63570136
#  0.22312418 0.14209502 0.62792867 0.647961   0.23196999 0.3073921
#  0.87188505 0.62505639 0.41974493 0.63253143 0.46060729 0.83586723
#  0.66579237 0.56019513 0.58639092 0.35712685 0.48891546 0.71990958
#  0.64939025 0.26582758 0.14485129 0.18551296 0.12089285 0.43254452
#  0.30826963 0.32667236 0.87562587 0.09984925 0.34943768 0.70475929
#  0.87560753 0.43488864 0.30277899 0.51067713 0.04314736 0.35004333
#  0.81567328 0.14491639 0.66925902 0.56967675 0.29176202 0.83013888
#  0.21350379 0.74155101 0.67554643 0.10240601 0.76082512 0.83153892
#  0.19875311 0.83974849 0.44009887 0.42724678 0.08025072 0.20695336
#  0.64434367 0.44651355 0.68984044 0.80711759 0.69500072 0.83445686
#  0.55318682 0.54815739 0.61621638 0.22591167 0.75405387 0.10675406
#  0.71751127 0.85410384 0.13325659 0.81618479 0.70953599 0.69156526
#  0.53864683 0.39793106 0.65073422 0.37495642 0.20412936 0.40880461
#  0.76314938 0.84299035 0.86043257 0.35288488 0.6374922  0.11656425
#  0.31841675 0.36384437 0.58368051 0.02976387 0.48420843 0.11854181
#  0.46884144 0.09223631 0.14218234 0.82802668]
# [0.7058068  0.35734278 0.13918215 0.64907392 0.75314781 0.84406968
#  0.51904244 0.1755239  0.10601457 0.85554018 0.25530507 0.86090618
# 0.011342247065380678 389.4275072306218
# [ 1.78855971  1.5041267  11.77340264 18.13921077  6.64390808 14.14878363
#  13.36253219  8.52485731  0.69560045 11.67729598  3.06582513  4.89920262
#   6.38836699 11.25837522 14.91550055 13.78972088 14.78296244 17.99538002
#  10.33591794  6.04970548  5.75117071 15.86081788  0.92992555  9.31044805
#  19.2009709   5.75845867 17.31036057  4.69784127 18.36049325  0.12885702
#  10.026315   19.2996178  18.74509763  8.63459752 12.45649    14.01733578
#   3.30490787 18.57540298 10.16716991 15.13980417  9.13285275  5.24595781
#  17.15705371  8.97463208 17.21613296  3.08286834  4.99494178  5.79127792
#   4.68156997 10.66811457 19.34508484 13.12785382 19.73391769 17.53243847
#  10.082961   17.12402026  6.62461561  4.53140396  6.81826359  6.0523989
#  19.43736666  0.10649999  5.18649547 13.6624498  16.81164331 12.84961069
#   9.87579463  9.20770357 11.39626194 14.74325057  9.51943065  7.54877056
#   7.50605007  2.11741123 13.74613095  0.92923376  3.29542261  8.02349662
#   7.92610564  0.94086987  1.35435568 12.3584632  15.14338765  9.73102693
#  13.95442916 17.44714537 17.5069149  16.44100021  1.32941594  8.96398788
#  18.7702321   0.20144876 12.96295796 15.18563871 19.16089006  0.95628731
#   2.63227813 18.76869536  2.09249074  1.92950974]
# 0.10649998622244361 19.733917685817527

# %%
c/2
# Out:
# array([0.89427986, 0.75206335, 5.88670132, 9.06960538, 3.32195404,
#        7.07439181, 6.6812661 , 4.26242865, 0.34780022, 5.83864799,
#        1.53291256, 2.44960131, 3.1941835 , 5.62918761, 7.45775028,
#        6.89486044, 7.39148122, 8.99769001, 5.16795897, 3.02485274,
#        2.87558536, 7.93040894, 0.46496277, 4.65522402, 9.60048545,
#        2.87922933, 8.65518029, 2.34892063, 9.18024662, 0.06442851,
#        5.0131575 , 9.6498089 , 9.37254882, 4.31729876, 6.228245  ,
#        7.00866789, 1.65245393, 9.28770149, 5.08358496, 7.56990209,
#        4.56642638, 2.6229789 , 8.57852685, 4.48731604, 8.60806648,
#        1.54143417, 2.49747089, 2.89563896, 2.34078498, 5.33405728,
#        9.67254242, 6.56392691, 9.86695884, 8.76621923, 5.0414805 ,
#        8.56201013, 3.31230781, 2.26570198, 3.4091318 , 3.02619945,
#        9.71868333, 0.05324999, 2.59324773, 6.8312249 , 8.40582166,
#        6.42480535, 4.93789731, 4.60385179, 5.69813097, 7.37162528,
#        4.75971533, 3.77438528, 3.75302504, 1.05870562, 6.87306548,
#        0.46461688, 1.6477113 , 4.01174831, 3.96305282, 0.47043493,
#        0.67717784, 6.1792316 , 7.57169383, 4.86551347, 6.97721458,
#        8.72357269, 8.75345745, 8.2205001 , 0.66470797, 4.48199394,
#        9.38511605, 0.10072438, 6.48147898, 7.59281936, 9.58044503,
#        0.47814366, 1.31613906, 9.38434768, 1.04624537, 0.96475487])

# %%
import numpy as np
import matplotlib.pyplot as plt
mat = np.random.random((10,10))
plt.imshow(mat, origin="lower", cmap='gray', interpolation='nearest')
plt.colorbar()
plt.show()
